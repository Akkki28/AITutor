# %%
import numpy as np
import gym
from gym import spaces

class AdaptiveLearning(gym.Env):
    def __init__(self, D=3, threshold=1e-3, max_steps=200):
        super(AdaptiveLearning, self).__init__()
        self.state_size = D
        self.action_size = 4 
        self.observation_space = spaces.Box(low=0, high=1, shape=(D,), dtype=np.float32)
        self.action_space = spaces.Discrete(self.action_size)
        self.state = np.zeros(D)
        self.target = np.ones(D)  
        self.threshold = threshold  
        self.steps = 0
        self.max_steps = max_steps  

    def step(self, action):
        assert self.action_space.contains(action), "Invalid Resource"
        if action == 0:
            self.state[0] += np.random.uniform(0.1, 0.4)
        elif action == 1:
            self.state[1] += np.random.uniform(0.1, 0.4)
        elif action == 2:
            self.state[2] += np.random.uniform(0.1, 0.4)
        else:
            self.state += np.random.uniform(0.05, 0.2, size=self.state_size)
        self.state = np.clip(self.state, 0, 1)
        
        infinity_norm = np.max(np.abs(self.state - self.target))

        
        if infinity_norm < self.threshold:
            reward = 0  
            done = True  
            print('successfull learning! Took only {} steps!'.format(self.steps))
        else:
            reward = -1  
            done = False
       
        self.steps += 1

        
        if self.steps >= self.max_steps:
            done = True

        return self.state, reward, done, {}

    def reset(self):
        self.state = np.zeros(self.state_size)  
        self.steps = 0
        return self.state

    def render(self, mode='human'):
        print(f"Current Traits: {self.state}")

# %%
env = AdaptiveLearning()

# %%
state_size = env.observation_space.shape[0]
state_size
# Out:
# 3

# %%
action_size = env.action_space.n
action_size
# Out:
# 4

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import random
from collections import deque
import os

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size, gamma=0.95, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, learning_rate=0.001, n_layers=24):
        super(DQN, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.learning_rate = learning_rate
        self.n_layers = n_layers
        self.model = self._build_model()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
    
    def _build_model(self):
        model = nn.Sequential(
            nn.Linear(self.state_size, self.n_layers),
            nn.ReLU(),
            nn.Linear(self.n_layers, self.n_layers),
            nn.ReLU(),
            nn.Linear(self.n_layers, self.action_size)
        )
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        state = torch.FloatTensor(state)
        with torch.no_grad():
            act_values = self.model(state)
        return torch.argmax(act_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return

        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state)
            next_state = torch.FloatTensor(next_state)
            reward = torch.FloatTensor([reward])
            action = torch.LongTensor([action])
            
            target = reward
            if not done:
                target = reward + self.gamma * torch.max(self.model(next_state)).item()

            current_q_value = self.model(state)[0][action]
            loss = F.mse_loss(current_q_value, target)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_state_dict(torch.load(name))

    def save(self, name):
        torch.save(self.model.state_dict(), name)

    def fit(self, env, n_episodes=1000, batch_size=32, penalty=0):
        output_dir = 'model_output/weights/'
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for e in range(n_episodes):
            state = env.reset()
            state = np.reshape(state, [1, self.state_size])
            cumulative_reward = 0  
            done = False
            while not done:
                action = self.act(state)
                next_state, reward, done, _ = env.step(action)
                reward = reward if not done else penalty
                
                cumulative_reward += reward  

                next_state = np.reshape(next_state, [1, self.state_size])
                self.remember(state, action, reward, next_state, done)
                state = next_state
                if done:
                    print(f"episode: {e}/{n_episodes} reward: {cumulative_reward}")
                    break
            if len(self.memory) > batch_size:
                self.replay(batch_size)
            if e % 100 == 0:
                self.save(output_dir + f"weights_{e:04d}.pth")

# %%
agent = DQN(state_size, action_size,gamma=0.9)

# %%
agent.fit(env,n_episodes=1000)
# Out:
# successfull learning! Took only 28 steps!
# episode: 0/1000 reward: -28
# successfull learning! Took only 21 steps!
# episode: 1/1000 reward: -21
# successfull learning! Took only 16 steps!
# episode: 2/1000 reward: -16
# successfull learning! Took only 18 steps!
# episode: 3/1000 reward: -18
# successfull learning! Took only 26 steps!
# episode: 4/1000 reward: -26
# successfull learning! Took only 27 steps!
# episode: 5/1000 reward: -27
# successfull learning! Took only 20 steps!
# episode: 6/1000 reward: -20
# successfull learning! Took only 21 steps!
# episode: 7/1000 reward: -21
# successfull learning! Took only 17 steps!
# episode: 8/1000 reward: -17
# successfull learning! Took only 24 steps!
# episode: 9/1000 reward: -24
# successfull learning! Took only 47 steps!
# episode: 10/1000 reward: -47
# successfull learning! Took only 22 steps!
# episode: 11/1000 reward: -22
# successfull learning! Took only 24 steps!
# episode: 12/1000 reward: -24
# successfull learning! Took only 17 steps!
# episode: 13/1000 reward: -17
# successfull learning! Took only 20 steps!
# episode: 14/1000 reward: -20
# successfull learning! Took only 20 steps!
# episode: 15/1000 reward: -20
# successfull learning! Took only 17 steps!
# episode: 16/1000 reward: -17
# successfull learning! Took only 22 steps!
# episode: 17/1000 reward: -22
# successfull learning! Took only 34 steps!
# episode: 18/1000 reward: -34
# successfull learning! Took only 38 steps!
# episode: 19/1000 reward: -38
# successfull learning! Took only 26 steps!
# episode: 20/1000 reward: -26
# successfull learning! Took only 33 steps!
# episode: 21/1000 reward: -33
# successfull learning! Took only 16 steps!
# episode: 22/1000 reward: -16
# successfull learning! Took only 14 steps!
# episode: 23/1000 reward: -14
# successfull learning! Took only 24 steps!
# episode: 24/1000 reward: -24
# successfull learning! Took only 17 steps!
# episode: 25/1000 reward: -17
# successfull learning! Took only 35 steps!
# episode: 26/1000 reward: -35
# successfull learning! Took only 34 steps!
# episode: 27/1000 reward: -34
# successfull learning! Took only 21 steps!
# episode: 28/1000 reward: -21
# successfull learning! Took only 40 steps!
# episode: 29/1000 reward: -40
# successfull learning! Took only 34 steps!
# episode: 30/1000 reward: -34
# successfull learning! Took only 19 steps!
# episode: 31/1000 reward: -19
# successfull learning! Took only 28 steps!
# episode: 32/1000 reward: -28
# successfull learning! Took only 30 steps!
# episode: 33/1000 reward: -30
# successfull learning! Took only 37 steps!
# episode: 34/1000 reward: -37
# successfull learning! Took only 24 steps!
# episode: 35/1000 reward: -24
# successfull learning! Took only 16 steps!
# episode: 36/1000 reward: -16
# successfull learning! Took only 38 steps!
# episode: 37/1000 reward: -38
# successfull learning! Took only 16 steps!
# episode: 38/1000 reward: -16
# successfull learning! Took only 30 steps!
# episode: 39/1000 reward: -30
# successfull learning! Took only 17 steps!
# episode: 40/1000 reward: -17
# successfull learning! Took only 23 steps!
# episode: 41/1000 reward: -23
# successfull learning! Took only 35 steps!
# episode: 42/1000 reward: -35
# successfull learning! Took only 31 steps!
# episode: 43/1000 reward: -31
# successfull learning! Took only 26 steps!
# episode: 44/1000 reward: -26
# successfull learning! Took only 17 steps!
# episode: 45/1000 reward: -17
# successfull learning! Took only 13 steps!
# episode: 46/1000 reward: -13
# successfull learning! Took only 26 steps!
# episode: 47/1000 reward: -26
# successfull learning! Took only 23 steps!
# episode: 48/1000 reward: -23
# successfull learning! Took only 22 steps!
# episode: 49/1000 reward: -22
# successfull learning! Took only 22 steps!
# episode: 50/1000 reward: -22
# successfull learning! Took only 26 steps!
# episode: 51/1000 reward: -26
# successfull learning! Took only 14 steps!
# episode: 52/1000 reward: -14
# successfull learning! Took only 17 steps!
# episode: 53/1000 reward: -17
# successfull learning! Took only 15 steps!
# episode: 54/1000 reward: -15
# successfull learning! Took only 22 steps!
# episode: 55/1000 reward: -22
# successfull learning! Took only 20 steps!
# episode: 56/1000 reward: -20
# successfull learning! Took only 17 steps!
# episode: 57/1000 reward: -17
# successfull learning! Took only 19 steps!
# episode: 58/1000 reward: -19
# successfull learning! Took only 49 steps!
# episode: 59/1000 reward: -49
# successfull learning! Took only 21 steps!
# episode: 60/1000 reward: -21
# successfull learning! Took only 51 steps!
# episode: 61/1000 reward: -51
# successfull learning! Took only 27 steps!
# episode: 62/1000 reward: -27
# successfull learning! Took only 26 steps!
# episode: 63/1000 reward: -26
# successfull learning! Took only 21 steps!
# episode: 64/1000 reward: -21
# successfull learning! Took only 25 steps!
# episode: 65/1000 reward: -25
# successfull learning! Took only 20 steps!
# episode: 66/1000 reward: -20
# successfull learning! Took only 36 steps!
# episode: 67/1000 reward: -36
# successfull learning! Took only 36 steps!
# episode: 68/1000 reward: -36
# successfull learning! Took only 17 steps!
# episode: 69/1000 reward: -17
# successfull learning! Took only 42 steps!
# episode: 70/1000 reward: -42
# successfull learning! Took only 23 steps!
# episode: 71/1000 reward: -23
# successfull learning! Took only 18 steps!
# episode: 72/1000 reward: -18
# successfull learning! Took only 16 steps!
# episode: 73/1000 reward: -16
# successfull learning! Took only 43 steps!
# episode: 74/1000 reward: -43
# successfull learning! Took only 24 steps!
# episode: 75/1000 reward: -24
# successfull learning! Took only 25 steps!
# episode: 76/1000 reward: -25
# successfull learning! Took only 24 steps!
# episode: 77/1000 reward: -24
# successfull learning! Took only 25 steps!
# episode: 78/1000 reward: -25
# successfull learning! Took only 29 steps!
# episode: 79/1000 reward: -29
# successfull learning! Took only 21 steps!
# episode: 80/1000 reward: -21
# successfull learning! Took only 18 steps!
# episode: 81/1000 reward: -18
# successfull learning! Took only 19 steps!
# episode: 82/1000 reward: -19
# successfull learning! Took only 56 steps!
# episode: 83/1000 reward: -56
# successfull learning! Took only 30 steps!
# episode: 84/1000 reward: -30
# successfull learning! Took only 20 steps!
# episode: 85/1000 reward: -20
# successfull learning! Took only 32 steps!
# episode: 86/1000 reward: -32
# successfull learning! Took only 25 steps!
# episode: 87/1000 reward: -25
# successfull learning! Took only 17 steps!
# episode: 88/1000 reward: -17
# successfull learning! Took only 33 steps!
# episode: 89/1000 reward: -33
# successfull learning! Took only 19 steps!
# episode: 90/1000 reward: -19
# successfull learning! Took only 38 steps!
# episode: 91/1000 reward: -38
# successfull learning! Took only 45 steps!
# episode: 92/1000 reward: -45
# successfull learning! Took only 34 steps!
# episode: 93/1000 reward: -34
# successfull learning! Took only 23 steps!
# episode: 94/1000 reward: -23
# successfull learning! Took only 31 steps!
# episode: 95/1000 reward: -31
# successfull learning! Took only 19 steps!
# episode: 96/1000 reward: -19
# successfull learning! Took only 18 steps!
# episode: 97/1000 reward: -18
# successfull learning! Took only 22 steps!
# episode: 98/1000 reward: -22
# successfull learning! Took only 30 steps!
# episode: 99/1000 reward: -30
# successfull learning! Took only 25 steps!
# episode: 100/1000 reward: -25
# successfull learning! Took only 20 steps!
# episode: 101/1000 reward: -20
# successfull learning! Took only 31 steps!
# episode: 102/1000 reward: -31
# successfull learning! Took only 32 steps!
# episode: 103/1000 reward: -32
# successfull learning! Took only 25 steps!
# episode: 104/1000 reward: -25
# successfull learning! Took only 17 steps!
# episode: 105/1000 reward: -17
# successfull learning! Took only 48 steps!
# episode: 106/1000 reward: -48
# successfull learning! Took only 28 steps!
# episode: 107/1000 reward: -28
# successfull learning! Took only 27 steps!
# episode: 108/1000 reward: -27
# successfull learning! Took only 20 steps!
# episode: 109/1000 reward: -20
# successfull learning! Took only 26 steps!
# episode: 110/1000 reward: -26
# successfull learning! Took only 21 steps!
# episode: 111/1000 reward: -21
# successfull learning! Took only 17 steps!
# episode: 112/1000 reward: -17
# successfull learning! Took only 49 steps!
# episode: 113/1000 reward: -49
# successfull learning! Took only 24 steps!
# episode: 114/1000 reward: -24
# successfull learning! Took only 17 steps!
# episode: 115/1000 reward: -17
# successfull learning! Took only 27 steps!
# episode: 116/1000 reward: -27
# successfull learning! Took only 39 steps!
# episode: 117/1000 reward: -39
# successfull learning! Took only 19 steps!
# episode: 118/1000 reward: -19
# successfull learning! Took only 37 steps!
# episode: 119/1000 reward: -37
# successfull learning! Took only 47 steps!
# episode: 120/1000 reward: -47
# successfull learning! Took only 16 steps!
# episode: 121/1000 reward: -16
# successfull learning! Took only 23 steps!
# episode: 122/1000 reward: -23
# successfull learning! Took only 30 steps!
# episode: 123/1000 reward: -30
# successfull learning! Took only 49 steps!
# episode: 124/1000 reward: -49
# successfull learning! Took only 72 steps!
# episode: 125/1000 reward: -72
# successfull learning! Took only 28 steps!
# episode: 126/1000 reward: -28
# successfull learning! Took only 34 steps!
# episode: 127/1000 reward: -34
# successfull learning! Took only 51 steps!
# episode: 128/1000 reward: -51
# successfull learning! Took only 55 steps!
# episode: 129/1000 reward: -55
# successfull learning! Took only 25 steps!
# episode: 130/1000 reward: -25
# successfull learning! Took only 30 steps!
# episode: 131/1000 reward: -30
# successfull learning! Took only 43 steps!
# episode: 132/1000 reward: -43
# successfull learning! Took only 20 steps!
# episode: 133/1000 reward: -20
# successfull learning! Took only 65 steps!
# episode: 134/1000 reward: -65
# successfull learning! Took only 70 steps!
# episode: 135/1000 reward: -70
# successfull learning! Took only 30 steps!
# episode: 136/1000 reward: -30
# successfull learning! Took only 18 steps!
# episode: 137/1000 reward: -18
# successfull learning! Took only 13 steps!
# episode: 138/1000 reward: -13
# successfull learning! Took only 55 steps!
# episode: 139/1000 reward: -55
# successfull learning! Took only 18 steps!
# episode: 140/1000 reward: -18
# successfull learning! Took only 40 steps!
# episode: 141/1000 reward: -40
# successfull learning! Took only 63 steps!
# episode: 142/1000 reward: -63
# successfull learning! Took only 60 steps!
# episode: 143/1000 reward: -60
# successfull learning! Took only 24 steps!
# episode: 144/1000 reward: -24
# successfull learning! Took only 22 steps!
# episode: 145/1000 reward: -22
# successfull learning! Took only 64 steps!
# episode: 146/1000 reward: -64
# successfull learning! Took only 40 steps!
# episode: 147/1000 reward: -40
# successfull learning! Took only 43 steps!
# episode: 148/1000 reward: -43
# successfull learning! Took only 23 steps!
# episode: 149/1000 reward: -23
# successfull learning! Took only 29 steps!
# episode: 150/1000 reward: -29
# successfull learning! Took only 44 steps!
# episode: 151/1000 reward: -44
# successfull learning! Took only 25 steps!
# episode: 152/1000 reward: -25
# successfull learning! Took only 32 steps!
# episode: 153/1000 reward: -32
# successfull learning! Took only 26 steps!
# episode: 154/1000 reward: -26
# successfull learning! Took only 30 steps!
# episode: 155/1000 reward: -30
# successfull learning! Took only 60 steps!
# episode: 156/1000 reward: -60
# successfull learning! Took only 44 steps!
# episode: 157/1000 reward: -44
# successfull learning! Took only 31 steps!
# episode: 158/1000 reward: -31
# successfull learning! Took only 26 steps!
# episode: 159/1000 reward: -26
# successfull learning! Took only 16 steps!
# episode: 160/1000 reward: -16
# successfull learning! Took only 43 steps!
# episode: 161/1000 reward: -43
# successfull learning! Took only 31 steps!
# episode: 162/1000 reward: -31
# successfull learning! Took only 26 steps!
# episode: 163/1000 reward: -26
# successfull learning! Took only 53 steps!
# episode: 164/1000 reward: -53
# successfull learning! Took only 19 steps!
# episode: 165/1000 reward: -19
# successfull learning! Took only 49 steps!
# episode: 166/1000 reward: -49
# successfull learning! Took only 50 steps!
# episode: 167/1000 reward: -50
# successfull learning! Took only 72 steps!
# episode: 168/1000 reward: -72
# successfull learning! Took only 56 steps!
# episode: 169/1000 reward: -56
# successfull learning! Took only 67 steps!
# episode: 170/1000 reward: -67
# successfull learning! Took only 39 steps!
# episode: 171/1000 reward: -39
# successfull learning! Took only 98 steps!
# episode: 172/1000 reward: -98
# successfull learning! Took only 44 steps!
# episode: 173/1000 reward: -44
# successfull learning! Took only 63 steps!
# episode: 174/1000 reward: -63
# successfull learning! Took only 74 steps!
# episode: 175/1000 reward: -74
# successfull learning! Took only 19 steps!
# episode: 176/1000 reward: -19
# successfull learning! Took only 37 steps!
# episode: 177/1000 reward: -37
# successfull learning! Took only 79 steps!
# episode: 178/1000 reward: -79
# successfull learning! Took only 56 steps!
# episode: 179/1000 reward: -56
# successfull learning! Took only 29 steps!
# episode: 180/1000 reward: -29
# successfull learning! Took only 13 steps!
# episode: 181/1000 reward: -13
# successfull learning! Took only 77 steps!
# episode: 182/1000 reward: -77
# successfull learning! Took only 40 steps!
# episode: 183/1000 reward: -40
# successfull learning! Took only 52 steps!
# episode: 184/1000 reward: -52
# successfull learning! Took only 18 steps!
# episode: 185/1000 reward: -18
# successfull learning! Took only 46 steps!
# episode: 186/1000 reward: -46
# successfull learning! Took only 40 steps!
# episode: 187/1000 reward: -40
# successfull learning! Took only 14 steps!
# episode: 188/1000 reward: -14
# successfull learning! Took only 29 steps!
# episode: 189/1000 reward: -29
# successfull learning! Took only 26 steps!
# episode: 190/1000 reward: -26
# successfull learning! Took only 46 steps!
# episode: 191/1000 reward: -46
# successfull learning! Took only 22 steps!
# episode: 192/1000 reward: -22
# successfull learning! Took only 27 steps!
# episode: 193/1000 reward: -27
# successfull learning! Took only 66 steps!
# episode: 194/1000 reward: -66
# successfull learning! Took only 105 steps!
# episode: 195/1000 reward: -105
# successfull learning! Took only 79 steps!
# episode: 196/1000 reward: -79
# successfull learning! Took only 32 steps!
# episode: 197/1000 reward: -32
# successfull learning! Took only 60 steps!
# episode: 198/1000 reward: -60
# successfull learning! Took only 54 steps!
# episode: 199/1000 reward: -54
# successfull learning! Took only 48 steps!
# episode: 200/1000 reward: -48
# successfull learning! Took only 37 steps!
# episode: 201/1000 reward: -37
# successfull learning! Took only 34 steps!
# episode: 202/1000 reward: -34
# successfull learning! Took only 45 steps!
# episode: 203/1000 reward: -45
# successfull learning! Took only 61 steps!
# episode: 204/1000 reward: -61
# successfull learning! Took only 27 steps!
# episode: 205/1000 reward: -27
# successfull learning! Took only 90 steps!
# episode: 206/1000 reward: -90
# successfull learning! Took only 51 steps!
# episode: 207/1000 reward: -51
# successfull learning! Took only 22 steps!
# episode: 208/1000 reward: -22
# successfull learning! Took only 63 steps!
# episode: 209/1000 reward: -63
# successfull learning! Took only 47 steps!
# episode: 210/1000 reward: -47
# successfull learning! Took only 86 steps!
# episode: 211/1000 reward: -86
# successfull learning! Took only 32 steps!
# episode: 212/1000 reward: -32
# successfull learning! Took only 41 steps!
# episode: 213/1000 reward: -41
# successfull learning! Took only 65 steps!
# episode: 214/1000 reward: -65
# successfull learning! Took only 40 steps!
# episode: 215/1000 reward: -40
# successfull learning! Took only 44 steps!
# episode: 216/1000 reward: -44
# successfull learning! Took only 75 steps!
# episode: 217/1000 reward: -75
# successfull learning! Took only 54 steps!
# episode: 218/1000 reward: -54
# successfull learning! Took only 55 steps!
# episode: 219/1000 reward: -55
# successfull learning! Took only 33 steps!
# episode: 220/1000 reward: -33
# successfull learning! Took only 95 steps!
# episode: 221/1000 reward: -95
# successfull learning! Took only 71 steps!
# episode: 222/1000 reward: -71
# successfull learning! Took only 30 steps!
# episode: 223/1000 reward: -30
# successfull learning! Took only 102 steps!
# episode: 224/1000 reward: -102
# successfull learning! Took only 42 steps!
# episode: 225/1000 reward: -42
# successfull learning! Took only 41 steps!
# episode: 226/1000 reward: -41
# successfull learning! Took only 73 steps!
# episode: 227/1000 reward: -73
# successfull learning! Took only 55 steps!
# episode: 228/1000 reward: -55
# successfull learning! Took only 61 steps!
# episode: 229/1000 reward: -61
# successfull learning! Took only 68 steps!
# episode: 230/1000 reward: -68
# successfull learning! Took only 44 steps!
# episode: 231/1000 reward: -44
# successfull learning! Took only 37 steps!
# episode: 232/1000 reward: -37
# successfull learning! Took only 70 steps!
# episode: 233/1000 reward: -70
# successfull learning! Took only 61 steps!
# episode: 234/1000 reward: -61
# successfull learning! Took only 31 steps!
# episode: 235/1000 reward: -31
# successfull learning! Took only 61 steps!
# episode: 236/1000 reward: -61
# successfull learning! Took only 110 steps!
# episode: 237/1000 reward: -110
# successfull learning! Took only 61 steps!
# episode: 238/1000 reward: -61
# successfull learning! Took only 101 steps!
# episode: 239/1000 reward: -101
# successfull learning! Took only 74 steps!
# episode: 240/1000 reward: -74
# successfull learning! Took only 116 steps!
# episode: 241/1000 reward: -116
# successfull learning! Took only 25 steps!
# episode: 242/1000 reward: -25
# successfull learning! Took only 39 steps!
# episode: 243/1000 reward: -39
# successfull learning! Took only 64 steps!
# episode: 244/1000 reward: -64
# successfull learning! Took only 70 steps!
# episode: 245/1000 reward: -70
# successfull learning! Took only 36 steps!
# episode: 246/1000 reward: -36
# successfull learning! Took only 67 steps!
# episode: 247/1000 reward: -67
# successfull learning! Took only 79 steps!
# episode: 248/1000 reward: -79
# successfull learning! Took only 22 steps!
# episode: 249/1000 reward: -22
# successfull learning! Took only 12 steps!
# episode: 250/1000 reward: -12
# successfull learning! Took only 64 steps!
# episode: 251/1000 reward: -64
# successfull learning! Took only 84 steps!
# episode: 252/1000 reward: -84
# successfull learning! Took only 29 steps!
# episode: 253/1000 reward: -29
# successfull learning! Took only 68 steps!
# episode: 254/1000 reward: -68
# successfull learning! Took only 17 steps!
# episode: 255/1000 reward: -17
# successfull learning! Took only 39 steps!
# episode: 256/1000 reward: -39
# successfull learning! Took only 48 steps!
# episode: 257/1000 reward: -48
# successfull learning! Took only 163 steps!
# episode: 258/1000 reward: -163
# successfull learning! Took only 118 steps!
# episode: 259/1000 reward: -118
# successfull learning! Took only 32 steps!
# episode: 260/1000 reward: -32
# successfull learning! Took only 92 steps!
# episode: 261/1000 reward: -92
# successfull learning! Took only 42 steps!
# episode: 262/1000 reward: -42
# successfull learning! Took only 52 steps!
# episode: 263/1000 reward: -52
# successfull learning! Took only 35 steps!
# episode: 264/1000 reward: -35
# successfull learning! Took only 124 steps!
# episode: 265/1000 reward: -124
# successfull learning! Took only 60 steps!
# episode: 266/1000 reward: -60
# successfull learning! Took only 39 steps!
# episode: 267/1000 reward: -39
# successfull learning! Took only 26 steps!
# episode: 268/1000 reward: -26
# successfull learning! Took only 72 steps!
# episode: 269/1000 reward: -72
# successfull learning! Took only 52 steps!
# episode: 270/1000 reward: -52
# successfull learning! Took only 51 steps!
# episode: 271/1000 reward: -51
# successfull learning! Took only 63 steps!
# episode: 272/1000 reward: -63
# successfull learning! Took only 57 steps!
# episode: 273/1000 reward: -57
# successfull learning! Took only 76 steps!
# episode: 274/1000 reward: -76
# successfull learning! Took only 91 steps!
# episode: 275/1000 reward: -91
# successfull learning! Took only 127 steps!
# episode: 276/1000 reward: -127
# successfull learning! Took only 95 steps!
# episode: 277/1000 reward: -95
# successfull learning! Took only 76 steps!
# episode: 278/1000 reward: -76
# successfull learning! Took only 39 steps!
# episode: 279/1000 reward: -39
# successfull learning! Took only 84 steps!
# episode: 280/1000 reward: -84
# successfull learning! Took only 58 steps!
# episode: 281/1000 reward: -58
# successfull learning! Took only 58 steps!
# episode: 282/1000 reward: -58
# successfull learning! Took only 92 steps!
# episode: 283/1000 reward: -92
# successfull learning! Took only 23 steps!
# episode: 284/1000 reward: -23
# successfull learning! Took only 43 steps!
# episode: 285/1000 reward: -43
# successfull learning! Took only 100 steps!
# episode: 286/1000 reward: -100
# successfull learning! Took only 36 steps!
# episode: 287/1000 reward: -36
# successfull learning! Took only 52 steps!
# episode: 288/1000 reward: -52
# successfull learning! Took only 50 steps!
# episode: 289/1000 reward: -50
# successfull learning! Took only 89 steps!
# episode: 290/1000 reward: -89
# successfull learning! Took only 72 steps!
# episode: 291/1000 reward: -72
# successfull learning! Took only 40 steps!
# episode: 292/1000 reward: -40
# successfull learning! Took only 129 steps!
# episode: 293/1000 reward: -129
# successfull learning! Took only 118 steps!
# episode: 294/1000 reward: -118
# successfull learning! Took only 65 steps!
# episode: 295/1000 reward: -65
# successfull learning! Took only 53 steps!
# episode: 296/1000 reward: -53
# successfull learning! Took only 127 steps!
# episode: 297/1000 reward: -127
# successfull learning! Took only 160 steps!
# episode: 298/1000 reward: -160
# successfull learning! Took only 72 steps!
# episode: 299/1000 reward: -72
# successfull learning! Took only 96 steps!
# episode: 300/1000 reward: -96
# successfull learning! Took only 33 steps!
# episode: 301/1000 reward: -33
# successfull learning! Took only 45 steps!
# episode: 302/1000 reward: -45
# successfull learning! Took only 125 steps!
# episode: 303/1000 reward: -125
# successfull learning! Took only 59 steps!
# episode: 304/1000 reward: -59
# successfull learning! Took only 22 steps!
# episode: 305/1000 reward: -22
# successfull learning! Took only 53 steps!
# episode: 306/1000 reward: -53
# successfull learning! Took only 56 steps!
# episode: 307/1000 reward: -56
# successfull learning! Took only 125 steps!
# episode: 308/1000 reward: -125
# successfull learning! Took only 26 steps!
# episode: 309/1000 reward: -26
# successfull learning! Took only 66 steps!
# episode: 310/1000 reward: -66
# successfull learning! Took only 32 steps!
# episode: 311/1000 reward: -32
# successfull learning! Took only 57 steps!
# episode: 312/1000 reward: -57
# successfull learning! Took only 100 steps!
# episode: 313/1000 reward: -100
# successfull learning! Took only 52 steps!
# episode: 314/1000 reward: -52
# successfull learning! Took only 132 steps!
# episode: 315/1000 reward: -132
# successfull learning! Took only 37 steps!
# episode: 316/1000 reward: -37
# successfull learning! Took only 68 steps!
# episode: 317/1000 reward: -68
# successfull learning! Took only 77 steps!
# episode: 318/1000 reward: -77
# successfull learning! Took only 68 steps!
# episode: 319/1000 reward: -68
# successfull learning! Took only 109 steps!
# episode: 320/1000 reward: -109
# successfull learning! Took only 52 steps!
# episode: 321/1000 reward: -52
# successfull learning! Took only 57 steps!
# episode: 322/1000 reward: -57
# successfull learning! Took only 86 steps!
# episode: 323/1000 reward: -86
# successfull learning! Took only 186 steps!
# episode: 324/1000 reward: -186
# successfull learning! Took only 230 steps!
# episode: 325/1000 reward: -230
# successfull learning! Took only 43 steps!
# episode: 326/1000 reward: -43
# successfull learning! Took only 120 steps!
# episode: 327/1000 reward: -120
# successfull learning! Took only 46 steps!
# episode: 328/1000 reward: -46
# successfull learning! Took only 42 steps!
# episode: 329/1000 reward: -42
# successfull learning! Took only 79 steps!
# episode: 330/1000 reward: -79
# successfull learning! Took only 101 steps!
# episode: 331/1000 reward: -101
# successfull learning! Took only 92 steps!
# episode: 332/1000 reward: -92
# successfull learning! Took only 109 steps!
# episode: 333/1000 reward: -109
# successfull learning! Took only 74 steps!
# episode: 334/1000 reward: -74
# successfull learning! Took only 30 steps!
# episode: 335/1000 reward: -30
# successfull learning! Took only 44 steps!
# episode: 336/1000 reward: -44
# successfull learning! Took only 51 steps!
# episode: 337/1000 reward: -51
# successfull learning! Took only 144 steps!
# episode: 338/1000 reward: -144
# successfull learning! Took only 96 steps!
# episode: 339/1000 reward: -96
# successfull learning! Took only 84 steps!
# episode: 340/1000 reward: -84
# successfull learning! Took only 184 steps!
# episode: 341/1000 reward: -184
# successfull learning! Took only 121 steps!
# episode: 342/1000 reward: -121
# successfull learning! Took only 51 steps!
# episode: 343/1000 reward: -51
# successfull learning! Took only 94 steps!
# episode: 344/1000 reward: -94
# successfull learning! Took only 133 steps!
# episode: 345/1000 reward: -133
# successfull learning! Took only 74 steps!
# episode: 346/1000 reward: -74
# successfull learning! Took only 87 steps!
# episode: 347/1000 reward: -87
# successfull learning! Took only 96 steps!
# episode: 348/1000 reward: -96
# successfull learning! Took only 92 steps!
# episode: 349/1000 reward: -92
# successfull learning! Took only 54 steps!
# episode: 350/1000 reward: -54
# successfull learning! Took only 109 steps!
# episode: 351/1000 reward: -109
# successfull learning! Took only 64 steps!
# episode: 352/1000 reward: -64
# successfull learning! Took only 78 steps!
# episode: 353/1000 reward: -78
# successfull learning! Took only 122 steps!
# episode: 354/1000 reward: -122
# successfull learning! Took only 147 steps!
# episode: 355/1000 reward: -147
# successfull learning! Took only 31 steps!
# episode: 356/1000 reward: -31
# successfull learning! Took only 77 steps!
# episode: 357/1000 reward: -77
# successfull learning! Took only 154 steps!
# episode: 358/1000 reward: -154
# successfull learning! Took only 54 steps!
# episode: 359/1000 reward: -54
# successfull learning! Took only 100 steps!
# episode: 360/1000 reward: -100
# successfull learning! Took only 44 steps!
# episode: 361/1000 reward: -44
# successfull learning! Took only 140 steps!
# episode: 362/1000 reward: -140
# successfull learning! Took only 44 steps!
# episode: 363/1000 reward: -44
# successfull learning! Took only 237 steps!
# episode: 364/1000 reward: -237
# successfull learning! Took only 181 steps!
# episode: 365/1000 reward: -181
# successfull learning! Took only 92 steps!
# episode: 366/1000 reward: -92
# successfull learning! Took only 69 steps!
# episode: 367/1000 reward: -69
# successfull learning! Took only 49 steps!
# episode: 368/1000 reward: -49
# successfull learning! Took only 139 steps!
# episode: 369/1000 reward: -139
# successfull learning! Took only 90 steps!
# episode: 370/1000 reward: -90
# successfull learning! Took only 105 steps!
# episode: 371/1000 reward: -105
# successfull learning! Took only 74 steps!
# episode: 372/1000 reward: -74
# successfull learning! Took only 68 steps!
# episode: 373/1000 reward: -68
# successfull learning! Took only 112 steps!
# episode: 374/1000 reward: -112
# successfull learning! Took only 84 steps!
# episode: 375/1000 reward: -84
# successfull learning! Took only 115 steps!
# episode: 376/1000 reward: -115
# successfull learning! Took only 127 steps!
# episode: 377/1000 reward: -127
# successfull learning! Took only 69 steps!
# episode: 378/1000 reward: -69
# successfull learning! Took only 64 steps!
# episode: 379/1000 reward: -64
# successfull learning! Took only 180 steps!
# episode: 380/1000 reward: -180
# successfull learning! Took only 174 steps!
# episode: 381/1000 reward: -174
# successfull learning! Took only 136 steps!
# episode: 382/1000 reward: -136
# successfull learning! Took only 277 steps!
# episode: 383/1000 reward: -277
# successfull learning! Took only 54 steps!
# episode: 384/1000 reward: -54
# successfull learning! Took only 165 steps!
# episode: 385/1000 reward: -165
# successfull learning! Took only 74 steps!
# episode: 386/1000 reward: -74
# successfull learning! Took only 23 steps!
# episode: 387/1000 reward: -23
# successfull learning! Took only 50 steps!
# episode: 388/1000 reward: -50
# successfull learning! Took only 52 steps!
# episode: 389/1000 reward: -52
# successfull learning! Took only 170 steps!
# episode: 390/1000 reward: -170
# successfull learning! Took only 87 steps!
# episode: 391/1000 reward: -87
# successfull learning! Took only 201 steps!
# episode: 392/1000 reward: -201
# successfull learning! Took only 130 steps!
# episode: 393/1000 reward: -130
# successfull learning! Took only 209 steps!
# episode: 394/1000 reward: -209
# successfull learning! Took only 64 steps!
# episode: 395/1000 reward: -64
# successfull learning! Took only 190 steps!
# episode: 396/1000 reward: -190
# successfull learning! Took only 92 steps!
# episode: 397/1000 reward: -92
# successfull learning! Took only 163 steps!
# episode: 398/1000 reward: -163
# successfull learning! Took only 139 steps!
# episode: 399/1000 reward: -139
# successfull learning! Took only 65 steps!
# episode: 400/1000 reward: -65
# successfull learning! Took only 152 steps!
# episode: 401/1000 reward: -152
# successfull learning! Took only 150 steps!
# episode: 402/1000 reward: -150
# successfull learning! Took only 112 steps!
# episode: 403/1000 reward: -112
# successfull learning! Took only 78 steps!
# episode: 404/1000 reward: -78
# successfull learning! Took only 137 steps!
# episode: 405/1000 reward: -137
# successfull learning! Took only 41 steps!
# episode: 406/1000 reward: -41
# successfull learning! Took only 36 steps!
# episode: 407/1000 reward: -36
# successfull learning! Took only 98 steps!
# episode: 408/1000 reward: -98
# successfull learning! Took only 188 steps!
# episode: 409/1000 reward: -188
# successfull learning! Took only 132 steps!
# episode: 410/1000 reward: -132
# successfull learning! Took only 117 steps!
# episode: 411/1000 reward: -117
# successfull learning! Took only 152 steps!
# episode: 412/1000 reward: -152
# successfull learning! Took only 142 steps!
# episode: 413/1000 reward: -142
# successfull learning! Took only 226 steps!
# episode: 414/1000 reward: -226
# successfull learning! Took only 134 steps!
# episode: 415/1000 reward: -134
# successfull learning! Took only 115 steps!
# episode: 416/1000 reward: -115
# successfull learning! Took only 201 steps!
# episode: 417/1000 reward: -201
# successfull learning! Took only 151 steps!
# episode: 418/1000 reward: -151
# successfull learning! Took only 138 steps!
# episode: 419/1000 reward: -138
# successfull learning! Took only 178 steps!
# episode: 420/1000 reward: -178
# successfull learning! Took only 186 steps!
# episode: 421/1000 reward: -186
# successfull learning! Took only 132 steps!
# episode: 422/1000 reward: -132
# successfull learning! Took only 128 steps!
# episode: 423/1000 reward: -128
# successfull learning! Took only 139 steps!
# episode: 424/1000 reward: -139
# successfull learning! Took only 88 steps!
# episode: 425/1000 reward: -88
# successfull learning! Took only 97 steps!
# episode: 426/1000 reward: -97
# successfull learning! Took only 140 steps!
# episode: 427/1000 reward: -140
# successfull learning! Took only 109 steps!
# episode: 428/1000 reward: -109
# successfull learning! Took only 158 steps!
# episode: 429/1000 reward: -158
# successfull learning! Took only 39 steps!
# episode: 430/1000 reward: -39
# successfull learning! Took only 36 steps!
# episode: 431/1000 reward: -36
# successfull learning! Took only 79 steps!
# episode: 432/1000 reward: -79
# successfull learning! Took only 189 steps!
# episode: 433/1000 reward: -189
# successfull learning! Took only 22 steps!
# episode: 434/1000 reward: -22
# successfull learning! Took only 46 steps!
# episode: 435/1000 reward: -46
# successfull learning! Took only 65 steps!
# episode: 436/1000 reward: -65
# successfull learning! Took only 284 steps!
# episode: 437/1000 reward: -284
# successfull learning! Took only 68 steps!
# episode: 438/1000 reward: -68
# successfull learning! Took only 94 steps!
# episode: 439/1000 reward: -94
# successfull learning! Took only 85 steps!
# episode: 440/1000 reward: -85
# successfull learning! Took only 189 steps!
# episode: 441/1000 reward: -189
# successfull learning! Took only 280 steps!
# episode: 442/1000 reward: -280
# successfull learning! Took only 123 steps!
# episode: 443/1000 reward: -123
# successfull learning! Took only 207 steps!
# episode: 444/1000 reward: -207
# successfull learning! Took only 205 steps!
# episode: 445/1000 reward: -205
# successfull learning! Took only 102 steps!
# episode: 446/1000 reward: -102
# successfull learning! Took only 37 steps!
# episode: 447/1000 reward: -37
# successfull learning! Took only 116 steps!
# episode: 448/1000 reward: -116
# successfull learning! Took only 88 steps!
# episode: 449/1000 reward: -88
# successfull learning! Took only 270 steps!
# episode: 450/1000 reward: -270
# successfull learning! Took only 182 steps!
# episode: 451/1000 reward: -182
# successfull learning! Took only 165 steps!
# episode: 452/1000 reward: -165
# successfull learning! Took only 266 steps!
# episode: 453/1000 reward: -266
# successfull learning! Took only 111 steps!
# episode: 454/1000 reward: -111
# successfull learning! Took only 63 steps!
# episode: 455/1000 reward: -63
# successfull learning! Took only 156 steps!
# episode: 456/1000 reward: -156
# successfull learning! Took only 192 steps!
# episode: 457/1000 reward: -192
# successfull learning! Took only 454 steps!
# episode: 458/1000 reward: -454
# successfull learning! Took only 194 steps!
# episode: 459/1000 reward: -194
# successfull learning! Took only 104 steps!
# episode: 460/1000 reward: -104
# successfull learning! Took only 91 steps!
# episode: 461/1000 reward: -91
# successfull learning! Took only 69 steps!
# episode: 462/1000 reward: -69
# successfull learning! Took only 300 steps!
# episode: 463/1000 reward: -300
# successfull learning! Took only 65 steps!
# episode: 464/1000 reward: -65
# successfull learning! Took only 100 steps!
# episode: 465/1000 reward: -100
# successfull learning! Took only 40 steps!
# episode: 466/1000 reward: -40
# successfull learning! Took only 330 steps!
# episode: 467/1000 reward: -330
# successfull learning! Took only 113 steps!
# episode: 468/1000 reward: -113
# successfull learning! Took only 165 steps!
# episode: 469/1000 reward: -165
# successfull learning! Took only 144 steps!
# episode: 470/1000 reward: -144
# successfull learning! Took only 119 steps!
# episode: 471/1000 reward: -119
# successfull learning! Took only 113 steps!
# episode: 472/1000 reward: -113
# successfull learning! Took only 69 steps!
# episode: 473/1000 reward: -69
# successfull learning! Took only 83 steps!
# episode: 474/1000 reward: -83
# successfull learning! Took only 33 steps!
# episode: 475/1000 reward: -33
# successfull learning! Took only 40 steps!
# episode: 476/1000 reward: -40
# successfull learning! Took only 102 steps!
# episode: 477/1000 reward: -102
# successfull learning! Took only 264 steps!
# episode: 478/1000 reward: -264
# successfull learning! Took only 200 steps!
# episode: 479/1000 reward: -200
# successfull learning! Took only 330 steps!
# episode: 480/1000 reward: -330
# successfull learning! Took only 281 steps!
# episode: 481/1000 reward: -281
# successfull learning! Took only 84 steps!
# episode: 482/1000 reward: -84
# successfull learning! Took only 491 steps!
# episode: 483/1000 reward: -491
# successfull learning! Took only 245 steps!
# episode: 484/1000 reward: -245
# successfull learning! Took only 111 steps!
# episode: 485/1000 reward: -111
# successfull learning! Took only 234 steps!
# episode: 486/1000 reward: -234
# successfull learning! Took only 202 steps!
# episode: 487/1000 reward: -202
# successfull learning! Took only 392 steps!
# episode: 488/1000 reward: -392
# successfull learning! Took only 93 steps!
# episode: 489/1000 reward: -93
# successfull learning! Took only 364 steps!
# episode: 490/1000 reward: -364
# successfull learning! Took only 245 steps!
# episode: 491/1000 reward: -245
# successfull learning! Took only 239 steps!
# episode: 492/1000 reward: -239
# successfull learning! Took only 224 steps!
# episode: 493/1000 reward: -224
# successfull learning! Took only 373 steps!
# episode: 494/1000 reward: -373
# successfull learning! Took only 79 steps!
# episode: 495/1000 reward: -79
# successfull learning! Took only 190 steps!
# episode: 496/1000 reward: -190
# successfull learning! Took only 375 steps!
# episode: 497/1000 reward: -375
# successfull learning! Took only 165 steps!
# episode: 498/1000 reward: -165
# successfull learning! Took only 294 steps!
# episode: 499/1000 reward: -294
# successfull learning! Took only 115 steps!
# episode: 500/1000 reward: -115
# successfull learning! Took only 262 steps!
# episode: 501/1000 reward: -262
# successfull learning! Took only 198 steps!
# episode: 502/1000 reward: -198
# successfull learning! Took only 109 steps!
# episode: 503/1000 reward: -109
# successfull learning! Took only 189 steps!
# episode: 504/1000 reward: -189
# successfull learning! Took only 283 steps!
# episode: 505/1000 reward: -283
# successfull learning! Took only 84 steps!
# episode: 506/1000 reward: -84
# successfull learning! Took only 165 steps!
# episode: 507/1000 reward: -165
# successfull learning! Took only 361 steps!
# episode: 508/1000 reward: -361
# successfull learning! Took only 114 steps!
# episode: 509/1000 reward: -114
# successfull learning! Took only 376 steps!
# episode: 510/1000 reward: -376
# successfull learning! Took only 269 steps!
# episode: 511/1000 reward: -269
# successfull learning! Took only 70 steps!
# episode: 512/1000 reward: -70
# successfull learning! Took only 255 steps!
# episode: 513/1000 reward: -255
# successfull learning! Took only 169 steps!
# episode: 514/1000 reward: -169
# successfull learning! Took only 286 steps!
# episode: 515/1000 reward: -286
# successfull learning! Took only 102 steps!
# episode: 516/1000 reward: -102
# successfull learning! Took only 231 steps!
# episode: 517/1000 reward: -231
# successfull learning! Took only 148 steps!
# episode: 518/1000 reward: -148
# successfull learning! Took only 115 steps!
# episode: 519/1000 reward: -115
# successfull learning! Took only 168 steps!
# episode: 520/1000 reward: -168
# successfull learning! Took only 153 steps!
# episode: 521/1000 reward: -153
# successfull learning! Took only 72 steps!
# episode: 522/1000 reward: -72
# successfull learning! Took only 44 steps!
# episode: 523/1000 reward: -44
# successfull learning! Took only 172 steps!
# episode: 524/1000 reward: -172
# successfull learning! Took only 450 steps!
# episode: 525/1000 reward: -450
# successfull learning! Took only 159 steps!
# episode: 526/1000 reward: -159
# successfull learning! Took only 157 steps!
# episode: 527/1000 reward: -157
# successfull learning! Took only 78 steps!
# episode: 528/1000 reward: -78
# successfull learning! Took only 237 steps!
# episode: 529/1000 reward: -237
# successfull learning! Took only 454 steps!
# episode: 530/1000 reward: -454
# successfull learning! Took only 20 steps!
# episode: 531/1000 reward: -20
# successfull learning! Took only 280 steps!
# episode: 532/1000 reward: -280
# successfull learning! Took only 11 steps!
# episode: 533/1000 reward: -11
# successfull learning! Took only 277 steps!
# episode: 534/1000 reward: -277
# successfull learning! Took only 207 steps!
# episode: 535/1000 reward: -207
# successfull learning! Took only 327 steps!
# episode: 536/1000 reward: -327
# successfull learning! Took only 79 steps!
# episode: 537/1000 reward: -79
# successfull learning! Took only 34 steps!
# episode: 538/1000 reward: -34
# successfull learning! Took only 321 steps!
# episode: 539/1000 reward: -321
# successfull learning! Took only 53 steps!
# episode: 540/1000 reward: -53
# successfull learning! Took only 185 steps!
# episode: 541/1000 reward: -185
# successfull learning! Took only 245 steps!
# episode: 542/1000 reward: -245
# successfull learning! Took only 268 steps!
# episode: 543/1000 reward: -268
# successfull learning! Took only 190 steps!
# episode: 544/1000 reward: -190
# successfull learning! Took only 67 steps!
# episode: 545/1000 reward: -67
# successfull learning! Took only 554 steps!
# episode: 546/1000 reward: -554
# successfull learning! Took only 183 steps!
# episode: 547/1000 reward: -183
# successfull learning! Took only 96 steps!
# episode: 548/1000 reward: -96
# successfull learning! Took only 122 steps!
# episode: 549/1000 reward: -122
# successfull learning! Took only 183 steps!
# episode: 550/1000 reward: -183
# successfull learning! Took only 14 steps!
# episode: 551/1000 reward: -14
# successfull learning! Took only 152 steps!
# episode: 552/1000 reward: -152
# successfull learning! Took only 95 steps!
# episode: 553/1000 reward: -95
# successfull learning! Took only 62 steps!
# episode: 554/1000 reward: -62
# successfull learning! Took only 420 steps!
# episode: 555/1000 reward: -420
# successfull learning! Took only 378 steps!
# episode: 556/1000 reward: -378
# successfull learning! Took only 18 steps!
# episode: 557/1000 reward: -18
# successfull learning! Took only 245 steps!
# episode: 558/1000 reward: -245
# successfull learning! Took only 511 steps!
# episode: 559/1000 reward: -511
# successfull learning! Took only 245 steps!
# episode: 560/1000 reward: -245
# successfull learning! Took only 406 steps!
# episode: 561/1000 reward: -406
# successfull learning! Took only 309 steps!
# episode: 562/1000 reward: -309
# successfull learning! Took only 390 steps!
# episode: 563/1000 reward: -390
# successfull learning! Took only 463 steps!
# episode: 564/1000 reward: -463
# successfull learning! Took only 208 steps!
# episode: 565/1000 reward: -208
# successfull learning! Took only 25 steps!
# episode: 566/1000 reward: -25
# successfull learning! Took only 11 steps!
# episode: 567/1000 reward: -11
# successfull learning! Took only 53 steps!
# episode: 568/1000 reward: -53
# successfull learning! Took only 123 steps!
# episode: 569/1000 reward: -123
# successfull learning! Took only 553 steps!
# episode: 570/1000 reward: -553
# successfull learning! Took only 107 steps!
# episode: 571/1000 reward: -107
# successfull learning! Took only 216 steps!
# episode: 572/1000 reward: -216
# successfull learning! Took only 249 steps!
# episode: 573/1000 reward: -249
# successfull learning! Took only 211 steps!
# episode: 574/1000 reward: -211
# successfull learning! Took only 11 steps!
# episode: 575/1000 reward: -11
# successfull learning! Took only 204 steps!
# episode: 576/1000 reward: -204
# successfull learning! Took only 96 steps!
# episode: 577/1000 reward: -96
# successfull learning! Took only 35 steps!
# episode: 578/1000 reward: -35
# successfull learning! Took only 131 steps!
# episode: 579/1000 reward: -131
# successfull learning! Took only 242 steps!
# episode: 580/1000 reward: -242
# successfull learning! Took only 250 steps!
# episode: 581/1000 reward: -250
# successfull learning! Took only 413 steps!
# episode: 582/1000 reward: -413
# successfull learning! Took only 770 steps!
# episode: 583/1000 reward: -770
# successfull learning! Took only 804 steps!
# episode: 584/1000 reward: -804
# successfull learning! Took only 42 steps!
# episode: 585/1000 reward: -42
# successfull learning! Took only 535 steps!
# episode: 586/1000 reward: -535
# successfull learning! Took only 341 steps!
# episode: 587/1000 reward: -341
# successfull learning! Took only 332 steps!
# episode: 588/1000 reward: -332
# successfull learning! Took only 147 steps!
# episode: 589/1000 reward: -147
# successfull learning! Took only 594 steps!
# episode: 590/1000 reward: -594
# successfull learning! Took only 156 steps!
# episode: 591/1000 reward: -156
# successfull learning! Took only 47 steps!
# episode: 592/1000 reward: -47
# successfull learning! Took only 17 steps!
# episode: 593/1000 reward: -17
# successfull learning! Took only 186 steps!
# episode: 594/1000 reward: -186
# successfull learning! Took only 388 steps!
# episode: 595/1000 reward: -388
# successfull learning! Took only 518 steps!
# episode: 596/1000 reward: -518
# successfull learning! Took only 71 steps!
# episode: 597/1000 reward: -71
# successfull learning! Took only 137 steps!
# episode: 598/1000 reward: -137
# successfull learning! Took only 125 steps!
# episode: 599/1000 reward: -125
# successfull learning! Took only 273 steps!
# episode: 600/1000 reward: -273
# successfull learning! Took only 134 steps!
# episode: 601/1000 reward: -134
# successfull learning! Took only 671 steps!
# episode: 602/1000 reward: -671
# successfull learning! Took only 349 steps!
# episode: 603/1000 reward: -349
# successfull learning! Took only 222 steps!
# episode: 604/1000 reward: -222
# successfull learning! Took only 67 steps!
# episode: 605/1000 reward: -67
# successfull learning! Took only 239 steps!
# episode: 606/1000 reward: -239
# successfull learning! Took only 168 steps!
# episode: 607/1000 reward: -168
# successfull learning! Took only 326 steps!
# episode: 608/1000 reward: -326
# successfull learning! Took only 392 steps!
# episode: 609/1000 reward: -392
# successfull learning! Took only 580 steps!
# episode: 610/1000 reward: -580
# successfull learning! Took only 287 steps!
# episode: 611/1000 reward: -287
# successfull learning! Took only 188 steps!
# episode: 612/1000 reward: -188
# successfull learning! Took only 265 steps!
# episode: 613/1000 reward: -265
# successfull learning! Took only 126 steps!
# episode: 614/1000 reward: -126
# successfull learning! Took only 441 steps!
# episode: 615/1000 reward: -441
# successfull learning! Took only 351 steps!
# episode: 616/1000 reward: -351
# successfull learning! Took only 389 steps!
# episode: 617/1000 reward: -389
# successfull learning! Took only 335 steps!
# episode: 618/1000 reward: -335
# successfull learning! Took only 65 steps!
# episode: 619/1000 reward: -65
# successfull learning! Took only 255 steps!
# episode: 620/1000 reward: -255
# successfull learning! Took only 642 steps!
# episode: 621/1000 reward: -642
# successfull learning! Took only 78 steps!
# episode: 622/1000 reward: -78
# successfull learning! Took only 927 steps!
# episode: 623/1000 reward: -927
# successfull learning! Took only 470 steps!
# episode: 624/1000 reward: -470
# successfull learning! Took only 542 steps!
# episode: 625/1000 reward: -542
# successfull learning! Took only 744 steps!
# episode: 626/1000 reward: -744
# successfull learning! Took only 672 steps!
# episode: 627/1000 reward: -672
# successfull learning! Took only 459 steps!
# episode: 628/1000 reward: -459
# successfull learning! Took only 154 steps!
# episode: 629/1000 reward: -154
# successfull learning! Took only 717 steps!
# episode: 630/1000 reward: -717
# successfull learning! Took only 603 steps!
# episode: 631/1000 reward: -603
# successfull learning! Took only 525 steps!
# episode: 632/1000 reward: -525
# successfull learning! Took only 981 steps!
# episode: 633/1000 reward: -981
# successfull learning! Took only 418 steps!
# episode: 634/1000 reward: -418
# successfull learning! Took only 749 steps!
# episode: 635/1000 reward: -749
# successfull learning! Took only 293 steps!
# episode: 636/1000 reward: -293
# successfull learning! Took only 323 steps!
# episode: 637/1000 reward: -323
# successfull learning! Took only 31 steps!
# episode: 638/1000 reward: -31
# successfull learning! Took only 141 steps!
# episode: 639/1000 reward: -141
# successfull learning! Took only 48 steps!
# episode: 640/1000 reward: -48
# successfull learning! Took only 66 steps!
# episode: 641/1000 reward: -66
# successfull learning! Took only 521 steps!
# episode: 642/1000 reward: -521
# successfull learning! Took only 41 steps!
# episode: 643/1000 reward: -41
# successfull learning! Took only 118 steps!
# episode: 644/1000 reward: -118
# successfull learning! Took only 18 steps!
# episode: 645/1000 reward: -18
# successfull learning! Took only 22 steps!
# episode: 646/1000 reward: -22
# successfull learning! Took only 401 steps!
# episode: 647/1000 reward: -401
# successfull learning! Took only 128 steps!
# episode: 648/1000 reward: -128
# successfull learning! Took only 192 steps!
# episode: 649/1000 reward: -192
# successfull learning! Took only 140 steps!
# episode: 650/1000 reward: -140
# successfull learning! Took only 281 steps!
# episode: 651/1000 reward: -281
# successfull learning! Took only 531 steps!
# episode: 652/1000 reward: -531
# successfull learning! Took only 1200 steps!
# episode: 653/1000 reward: -1200
# successfull learning! Took only 483 steps!
# episode: 654/1000 reward: -483
# successfull learning! Took only 323 steps!
# episode: 655/1000 reward: -323
# successfull learning! Took only 206 steps!
# episode: 656/1000 reward: -206
# successfull learning! Took only 272 steps!
# episode: 657/1000 reward: -272
# successfull learning! Took only 638 steps!
# episode: 658/1000 reward: -638
# successfull learning! Took only 357 steps!
# episode: 659/1000 reward: -357
# successfull learning! Took only 427 steps!
# episode: 660/1000 reward: -427
# ...
# episode: 787/1000 reward: -962
# successfull learning! Took only 524 steps!
# episode: 788/1000 reward: -524
# successfull learning! Took only 466 steps!
# episode: 789/1000 reward: -466
# successfull learning! Took only 2241 steps!
# episode: 790/1000 reward: -2241
# successfull learning! Took only 125 steps!
# episode: 791/1000 reward: -125
# successfull learning! Took only 851 steps!
# episode: 792/1000 reward: -851
# successfull learning! Took only 1072 steps!
# episode: 793/1000 reward: -1072
# successfull learning! Took only 623 steps!
# episode: 794/1000 reward: -623
# successfull learning! Took only 836 steps!
# episode: 795/1000 reward: -836
# successfull learning! Took only 1306 steps!
# episode: 796/1000 reward: -1306
# successfull learning! Took only 2330 steps!
# episode: 797/1000 reward: -2330
# successfull learning! Took only 1335 steps!
# episode: 798/1000 reward: -1335
# successfull learning! Took only 766 steps!
# episode: 799/1000 reward: -766
# successfull learning! Took only 355 steps!
# episode: 800/1000 reward: -355
# successfull learning! Took only 1323 steps!
# episode: 801/1000 reward: -1323
# successfull learning! Took only 1459 steps!
# episode: 802/1000 reward: -1459
# successfull learning! Took only 1561 steps!
# episode: 803/1000 reward: -1561
# successfull learning! Took only 2912 steps!
# episode: 804/1000 reward: -2912
# successfull learning! Took only 686 steps!
# episode: 805/1000 reward: -686
# successfull learning! Took only 1106 steps!
# episode: 806/1000 reward: -1106
# successfull learning! Took only 1845 steps!
# episode: 807/1000 reward: -1845
# successfull learning! Took only 1226 steps!
# episode: 808/1000 reward: -1226
# successfull learning! Took only 1971 steps!
# episode: 809/1000 reward: -1971
# successfull learning! Took only 259 steps!
# episode: 810/1000 reward: -259
# successfull learning! Took only 968 steps!
# episode: 811/1000 reward: -968
# successfull learning! Took only 312 steps!
# episode: 812/1000 reward: -312
# successfull learning! Took only 1074 steps!
# episode: 813/1000 reward: -1074
# successfull learning! Took only 938 steps!
# episode: 814/1000 reward: -938
# successfull learning! Took only 326 steps!
# episode: 815/1000 reward: -326
# successfull learning! Took only 919 steps!
# episode: 816/1000 reward: -919
# successfull learning! Took only 1196 steps!
# episode: 817/1000 reward: -1196
# successfull learning! Took only 917 steps!
# episode: 818/1000 reward: -917
# successfull learning! Took only 2252 steps!
# episode: 819/1000 reward: -2252
# successfull learning! Took only 468 steps!
# episode: 820/1000 reward: -468
# successfull learning! Took only 2028 steps!
# episode: 821/1000 reward: -2028
# successfull learning! Took only 1044 steps!
# episode: 822/1000 reward: -1044
# successfull learning! Took only 752 steps!
# episode: 823/1000 reward: -752
# successfull learning! Took only 726 steps!
# episode: 824/1000 reward: -726
# successfull learning! Took only 904 steps!
# episode: 825/1000 reward: -904
# successfull learning! Took only 1319 steps!
# episode: 826/1000 reward: -1319
# successfull learning! Took only 538 steps!
# episode: 827/1000 reward: -538
# successfull learning! Took only 1913 steps!
# episode: 828/1000 reward: -1913
# successfull learning! Took only 1766 steps!
# episode: 829/1000 reward: -1766
# successfull learning! Took only 1489 steps!
# episode: 830/1000 reward: -1489
# successfull learning! Took only 1523 steps!
# episode: 831/1000 reward: -1523
# successfull learning! Took only 1834 steps!
# episode: 832/1000 reward: -1834
# successfull learning! Took only 883 steps!
# episode: 833/1000 reward: -883
# successfull learning! Took only 1606 steps!
# episode: 834/1000 reward: -1606
# successfull learning! Took only 1746 steps!
# episode: 835/1000 reward: -1746
# successfull learning! Took only 1779 steps!
# episode: 836/1000 reward: -1779
# successfull learning! Took only 965 steps!
# episode: 837/1000 reward: -965
# successfull learning! Took only 1165 steps!
# episode: 838/1000 reward: -1165
# successfull learning! Took only 2025 steps!
# episode: 839/1000 reward: -2025
# successfull learning! Took only 1371 steps!
# episode: 840/1000 reward: -1371
# successfull learning! Took only 544 steps!
# episode: 841/1000 reward: -544
# successfull learning! Took only 1649 steps!
# episode: 842/1000 reward: -1649
# successfull learning! Took only 1544 steps!
# episode: 843/1000 reward: -1544
# successfull learning! Took only 1012 steps!
# episode: 844/1000 reward: -1012
# successfull learning! Took only 1027 steps!
# episode: 845/1000 reward: -1027
# successfull learning! Took only 299 steps!
# episode: 846/1000 reward: -299
# successfull learning! Took only 1782 steps!
# episode: 847/1000 reward: -1782
# successfull learning! Took only 580 steps!
# episode: 848/1000 reward: -580
# successfull learning! Took only 559 steps!
# episode: 849/1000 reward: -559
# successfull learning! Took only 82 steps!
# episode: 850/1000 reward: -82
# successfull learning! Took only 249 steps!
# episode: 851/1000 reward: -249
# successfull learning! Took only 850 steps!
# episode: 852/1000 reward: -850
# successfull learning! Took only 2481 steps!
# episode: 853/1000 reward: -2481
# successfull learning! Took only 796 steps!
# episode: 854/1000 reward: -796
# successfull learning! Took only 1355 steps!
# episode: 855/1000 reward: -1355
# successfull learning! Took only 2399 steps!
# episode: 856/1000 reward: -2399
# successfull learning! Took only 593 steps!
# episode: 857/1000 reward: -593
# successfull learning! Took only 1108 steps!
# episode: 858/1000 reward: -1108
# successfull learning! Took only 339 steps!
# episode: 859/1000 reward: -339
# successfull learning! Took only 970 steps!
# episode: 860/1000 reward: -970
# successfull learning! Took only 667 steps!
# episode: 861/1000 reward: -667
# successfull learning! Took only 634 steps!
# episode: 862/1000 reward: -634
# successfull learning! Took only 1152 steps!
# episode: 863/1000 reward: -1152
# successfull learning! Took only 2857 steps!
# episode: 864/1000 reward: -2857
# successfull learning! Took only 1005 steps!
# episode: 865/1000 reward: -1005
# successfull learning! Took only 1483 steps!
# episode: 866/1000 reward: -1483
# successfull learning! Took only 2167 steps!
# episode: 867/1000 reward: -2167
# successfull learning! Took only 1798 steps!
# episode: 868/1000 reward: -1798
# successfull learning! Took only 723 steps!
# episode: 869/1000 reward: -723
# successfull learning! Took only 1025 steps!
# episode: 870/1000 reward: -1025
# successfull learning! Took only 1708 steps!
# episode: 871/1000 reward: -1708
# successfull learning! Took only 1255 steps!
# episode: 872/1000 reward: -1255
# successfull learning! Took only 1164 steps!
# episode: 873/1000 reward: -1164
# successfull learning! Took only 1574 steps!
# episode: 874/1000 reward: -1574
# successfull learning! Took only 2394 steps!
# episode: 875/1000 reward: -2394
# successfull learning! Took only 1401 steps!
# episode: 876/1000 reward: -1401
# successfull learning! Took only 694 steps!
# episode: 877/1000 reward: -694
# successfull learning! Took only 621 steps!
# episode: 878/1000 reward: -621
# successfull learning! Took only 639 steps!
# episode: 879/1000 reward: -639
# successfull learning! Took only 681 steps!
# episode: 880/1000 reward: -681
# successfull learning! Took only 573 steps!
# episode: 881/1000 reward: -573
# successfull learning! Took only 1922 steps!
# episode: 882/1000 reward: -1922
# successfull learning! Took only 1707 steps!
# episode: 883/1000 reward: -1707
# successfull learning! Took only 986 steps!
# episode: 884/1000 reward: -986
# successfull learning! Took only 1901 steps!
# episode: 885/1000 reward: -1901
# successfull learning! Took only 295 steps!
# episode: 886/1000 reward: -295
# successfull learning! Took only 580 steps!
# episode: 887/1000 reward: -580
# successfull learning! Took only 554 steps!
# episode: 888/1000 reward: -554
# successfull learning! Took only 603 steps!
# episode: 889/1000 reward: -603
# successfull learning! Took only 3929 steps!
# episode: 890/1000 reward: -3929
# successfull learning! Took only 2552 steps!
# episode: 891/1000 reward: -2552
# successfull learning! Took only 491 steps!
# episode: 892/1000 reward: -491
# successfull learning! Took only 792 steps!
# episode: 893/1000 reward: -792
# successfull learning! Took only 1261 steps!
# episode: 894/1000 reward: -1261
# successfull learning! Took only 1048 steps!
# episode: 895/1000 reward: -1048
# successfull learning! Took only 1354 steps!
# episode: 896/1000 reward: -1354
# successfull learning! Took only 587 steps!
# episode: 897/1000 reward: -587
# successfull learning! Took only 175 steps!
# episode: 898/1000 reward: -175
# successfull learning! Took only 557 steps!
# episode: 899/1000 reward: -557
# successfull learning! Took only 1228 steps!
# episode: 900/1000 reward: -1228
# successfull learning! Took only 1069 steps!
# episode: 901/1000 reward: -1069
# successfull learning! Took only 383 steps!
# episode: 902/1000 reward: -383
# successfull learning! Took only 1770 steps!
# episode: 903/1000 reward: -1770
# successfull learning! Took only 1705 steps!
# episode: 904/1000 reward: -1705
# successfull learning! Took only 3763 steps!
# episode: 905/1000 reward: -3763
# successfull learning! Took only 1039 steps!
# episode: 906/1000 reward: -1039
# successfull learning! Took only 912 steps!
# episode: 907/1000 reward: -912
# successfull learning! Took only 1029 steps!
# episode: 908/1000 reward: -1029
# successfull learning! Took only 676 steps!
# episode: 909/1000 reward: -676
# successfull learning! Took only 1784 steps!
# episode: 910/1000 reward: -1784
# successfull learning! Took only 1440 steps!
# episode: 911/1000 reward: -1440
# successfull learning! Took only 952 steps!
# episode: 912/1000 reward: -952
# successfull learning! Took only 783 steps!
# episode: 913/1000 reward: -783
# successfull learning! Took only 4088 steps!
# episode: 914/1000 reward: -4088
# successfull learning! Took only 689 steps!
# episode: 915/1000 reward: -689
# successfull learning! Took only 650 steps!
# episode: 916/1000 reward: -650
# successfull learning! Took only 743 steps!
# episode: 917/1000 reward: -743
# successfull learning! Took only 1420 steps!
# episode: 918/1000 reward: -1420
# successfull learning! Took only 740 steps!
# episode: 919/1000 reward: -740
# successfull learning! Took only 1168 steps!
# episode: 920/1000 reward: -1168
# successfull learning! Took only 2854 steps!
# episode: 921/1000 reward: -2854
# successfull learning! Took only 5730 steps!
# episode: 922/1000 reward: -5730
# successfull learning! Took only 1763 steps!
# episode: 923/1000 reward: -1763
# successfull learning! Took only 1538 steps!
# episode: 924/1000 reward: -1538
# successfull learning! Took only 1543 steps!
# episode: 925/1000 reward: -1543
# successfull learning! Took only 3517 steps!
# episode: 926/1000 reward: -3517
# successfull learning! Took only 1597 steps!
# episode: 927/1000 reward: -1597
# successfull learning! Took only 1009 steps!
# episode: 928/1000 reward: -1009
# successfull learning! Took only 1556 steps!
# episode: 929/1000 reward: -1556
# successfull learning! Took only 997 steps!
# episode: 930/1000 reward: -997
# successfull learning! Took only 586 steps!
# episode: 931/1000 reward: -586
# successfull learning! Took only 921 steps!
# episode: 932/1000 reward: -921
# successfull learning! Took only 1706 steps!
# episode: 933/1000 reward: -1706
# successfull learning! Took only 1412 steps!
# episode: 934/1000 reward: -1412
# successfull learning! Took only 633 steps!
# episode: 935/1000 reward: -633
# successfull learning! Took only 533 steps!
# episode: 936/1000 reward: -533
# successfull learning! Took only 2522 steps!
# episode: 937/1000 reward: -2522
# successfull learning! Took only 1237 steps!
# episode: 938/1000 reward: -1237
# successfull learning! Took only 2014 steps!
# episode: 939/1000 reward: -2014
# successfull learning! Took only 834 steps!
# episode: 940/1000 reward: -834
# successfull learning! Took only 1848 steps!
# episode: 941/1000 reward: -1848
# successfull learning! Took only 531 steps!
# episode: 942/1000 reward: -531
# successfull learning! Took only 2256 steps!
# episode: 943/1000 reward: -2256
# successfull learning! Took only 733 steps!
# episode: 944/1000 reward: -733
# successfull learning! Took only 668 steps!
# episode: 945/1000 reward: -668
# successfull learning! Took only 520 steps!
# episode: 946/1000 reward: -520
# successfull learning! Took only 1908 steps!
# episode: 947/1000 reward: -1908
# successfull learning! Took only 1330 steps!
# episode: 948/1000 reward: -1330
# successfull learning! Took only 1165 steps!
# episode: 949/1000 reward: -1165
# successfull learning! Took only 2298 steps!
# episode: 950/1000 reward: -2298
# successfull learning! Took only 2991 steps!
# episode: 951/1000 reward: -2991
# successfull learning! Took only 1023 steps!
# episode: 952/1000 reward: -1023
# successfull learning! Took only 1996 steps!
# episode: 953/1000 reward: -1996
# successfull learning! Took only 1647 steps!
# episode: 954/1000 reward: -1647
# successfull learning! Took only 2750 steps!
# episode: 955/1000 reward: -2750
# successfull learning! Took only 1062 steps!
# episode: 956/1000 reward: -1062
# successfull learning! Took only 3182 steps!
# episode: 957/1000 reward: -3182
# successfull learning! Took only 2655 steps!
# episode: 958/1000 reward: -2655
# successfull learning! Took only 1592 steps!
# episode: 959/1000 reward: -1592
# successfull learning! Took only 1572 steps!
# episode: 960/1000 reward: -1572
# successfull learning! Took only 181 steps!
# episode: 961/1000 reward: -181
# successfull learning! Took only 1000 steps!
# episode: 962/1000 reward: -1000
# successfull learning! Took only 1854 steps!
# episode: 963/1000 reward: -1854
# successfull learning! Took only 3182 steps!
# episode: 964/1000 reward: -3182
# successfull learning! Took only 746 steps!
# episode: 965/1000 reward: -746
# successfull learning! Took only 1352 steps!
# episode: 966/1000 reward: -1352
# successfull learning! Took only 1222 steps!
# episode: 967/1000 reward: -1222
# successfull learning! Took only 922 steps!
# episode: 968/1000 reward: -922
# successfull learning! Took only 2974 steps!
# episode: 969/1000 reward: -2974
# successfull learning! Took only 1134 steps!
# episode: 970/1000 reward: -1134
# successfull learning! Took only 3162 steps!
# episode: 971/1000 reward: -3162
# successfull learning! Took only 1012 steps!
# episode: 972/1000 reward: -1012
# successfull learning! Took only 2292 steps!
# episode: 973/1000 reward: -2292
# successfull learning! Took only 1090 steps!
# episode: 974/1000 reward: -1090
# successfull learning! Took only 1577 steps!
# episode: 975/1000 reward: -1577
# successfull learning! Took only 2591 steps!
# episode: 976/1000 reward: -2591
# successfull learning! Took only 1559 steps!
# episode: 977/1000 reward: -1559
# successfull learning! Took only 907 steps!
# episode: 978/1000 reward: -907
# successfull learning! Took only 2685 steps!
# episode: 979/1000 reward: -2685
# successfull learning! Took only 1905 steps!
# episode: 980/1000 reward: -1905
# successfull learning! Took only 1360 steps!
# episode: 981/1000 reward: -1360
# successfull learning! Took only 1192 steps!
# episode: 982/1000 reward: -1192
# successfull learning! Took only 3168 steps!
# episode: 983/1000 reward: -3168
# successfull learning! Took only 1975 steps!
# episode: 984/1000 reward: -1975
# successfull learning! Took only 1942 steps!
# episode: 985/1000 reward: -1942
# successfull learning! Took only 184 steps!
# episode: 986/1000 reward: -184
# successfull learning! Took only 720 steps!
# episode: 987/1000 reward: -720
# successfull learning! Took only 282 steps!
# episode: 988/1000 reward: -282
# successfull learning! Took only 1770 steps!
# episode: 989/1000 reward: -1770
# successfull learning! Took only 1587 steps!
# episode: 990/1000 reward: -1587
# successfull learning! Took only 2353 steps!
# episode: 991/1000 reward: -2353
# successfull learning! Took only 860 steps!
# episode: 992/1000 reward: -860
# successfull learning! Took only 663 steps!
# episode: 993/1000 reward: -663
# successfull learning! Took only 956 steps!
# episode: 994/1000 reward: -956
# successfull learning! Took only 1918 steps!
# episode: 995/1000 reward: -1918
# successfull learning! Took only 2339 steps!
# episode: 996/1000 reward: -2339
# successfull learning! Took only 1275 steps!
# episode: 997/1000 reward: -1275
# successfull learning! Took only 1468 steps!
# episode: 998/1000 reward: -1468
# successfull learning! Took only 2100 steps!
# episode: 999/1000 reward: -2100
